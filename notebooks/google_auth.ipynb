# %%
import os
os.chdir(r'/Users/yashgourav/expense_manager')
print(f'current working directory set to : {os.getcwd()}')
# Out:
# current working directory set to : /Users/yashgourav/expense_manager

# %%
import google.auth
import gspread
from typing import cast
from google.auth.credentials import Credentials

scopes =[
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive",
        ],

creds, _ = google.auth.default(scopes=scopes)
creds = cast(Credentials, creds)

client = gspread.authorize(creds)

# %%
sheet = client.open_by_key("1YLVz3i6R9sYXW3oWfUEtFTMkrXyY6ONB4FohhTf4B8w")

# %%
sheet_instance = sheet.get_worksheet(0)  # Get the first worksheet

# %%
sheet_instance
# Out:
# <Worksheet 'taxonomy' id:0>

# %%
import google.auth

creds, project = google.auth.default()
print(f"Project ID: {project}")
print(f"Current Scopes: {creds.scopes}")
# Out:
# Project ID: expense-tracker-438619
# Current Scopes: None
